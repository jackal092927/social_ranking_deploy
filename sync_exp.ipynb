# %%
# %matplotlib inline

# %%
# %%bash
#
# python lab6/exp1.py
# Out:
# Parameters saved to: ./lab6/results/lab6exp1-20250515-222136__agg__borda__custom-init/parameters.json
# Testing alpha-beta values as follows:
# Alpha: 0.60, Beta range: 0.11 to 5.99, Total points: 14
# Alpha: 0.70, Beta range: 0.11 to 6.99, Total points: 15
# Alpha: 0.80, Beta range: 0.11 to 7.98, Total points: 16
# Alpha: 0.90, Beta range: 0.11 to 8.98, Total points: 17
# Alpha: 1.00, Beta range: 0.11 to 9.98, Total points: 18
# Using metric: agg
# Score rule: borda
# Init type: custom
# Results will be saved to: ./lab6/results/lab6exp1-20250515-222136__agg__borda__custom-init
#
# --- Testing with alpha = 0.60 (1/5) ---
#   Saved agg strategy performance plot for alpha=0.60
#   Saved relative agg performance plot for alpha=0.60
#
# --- Testing with alpha = 0.70 (2/5) ---
#   Saved agg strategy performance plot for alpha=0.70
#   Saved relative agg performance plot for alpha=0.70
#
# --- Testing with alpha = 0.80 (3/5) ---
#   Saved agg strategy performance plot for alpha=0.80
# ...

# %%
# %%bash
#
# python lab6/exp1.py --metric card
# Out:
# Parameters saved to: ./lab6/results/lab6exp1-20250515-222800__card__borda__custom-init/parameters.json
# Testing alpha-beta values as follows:
# Alpha: 0.60, Beta range: 0.11 to 5.99, Total points: 14
# Alpha: 0.70, Beta range: 0.11 to 6.99, Total points: 15
# Alpha: 0.80, Beta range: 0.11 to 7.98, Total points: 16
# Alpha: 0.90, Beta range: 0.11 to 8.98, Total points: 17
# Alpha: 1.00, Beta range: 0.11 to 9.98, Total points: 18
# Using metric: card
# Score rule: borda
# Init type: custom
# Results will be saved to: ./lab6/results/lab6exp1-20250515-222800__card__borda__custom-init
#
# --- Testing with alpha = 0.60 (1/5) ---
#   Saved card strategy performance plot for alpha=0.60
#   Saved relative card performance plot for alpha=0.60
#
# --- Testing with alpha = 0.70 (2/5) ---
#   Saved card strategy performance plot for alpha=0.70
#   Saved relative card performance plot for alpha=0.70
#
# --- Testing with alpha = 0.80 (3/5) ---
# ...

# %%
# %%bash
#
# python lab6/exp1.py --score_rule lp
# Out:
# Parameters saved to: ./lab6/results/lab6exp1-20250515-205357__agg__lp_concave2.0__custom-init/parameters.json
# Testing alpha-beta values as follows:
# Alpha: 0.60, Beta range: 0.11 to 5.99, Total points: 14
# Alpha: 0.70, Beta range: 0.11 to 6.99, Total points: 15
# Alpha: 0.80, Beta range: 0.11 to 7.98, Total points: 16
# Alpha: 0.90, Beta range: 0.11 to 8.98, Total points: 17
# Alpha: 1.00, Beta range: 0.11 to 9.98, Total points: 18
# Using metric: agg
# Score rule: lp_concave2.0
# Init type: custom
# Results will be saved to: ./lab6/results/lab6exp1-20250515-205357__agg__lp_concave2.0__custom-init
#
# --- Testing with alpha = 0.60 (1/5) ---
#   Saved agg strategy performance plot for alpha=0.60
#   Saved relative agg performance plot for alpha=0.60
#
# --- Testing with alpha = 0.70 (2/5) ---
#   Saved agg strategy performance plot for alpha=0.70
#   Saved relative agg performance plot for alpha=0.70
#
# --- Testing with alpha = 0.80 (3/5) ---
# ...

# %%
# %%bash
#
# python plot_caggrim_ratio_heatmap.py --multi --prefix method_compare_lp2 --filepath lab6/results/lab6exp1-20250515-205108__agg__lp_convex2.0__custom-init/alpha_beta_sensitivity_results.csv
# Out:
# Plot saved as method_compare_lp2_caggrim_sequential_random_comparison.png
# Figure(1600x1200)

# %%
from plot_caggrim_ratio_heatmap import plot_multiple_methods
dirname = "lab6exp1-20250515-222136__agg__borda__custom-init"
plot_multiple_methods(
    methods=['CAGGRIM', 'Sequential', 'Random'],
    save_prefix='method_compare_lp2',
    filepath=f'lab6/results/{dirname}/alpha_beta_sensitivity_results.csv'
)
# Out:
# Plot saved as ./method_compare_lp2_caggrim_sequential_random_comparison_20250515-223129.png
